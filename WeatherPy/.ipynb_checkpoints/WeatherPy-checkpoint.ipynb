# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)
# print (lats)
# print (lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        # print (city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
    # print (city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather_response = requests.get(city_url)
        print (city_weather_response)
        city_weather = city_weather_response.json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# <Response [200]>
# Processing Record 2 of Set 1 | saudarkrokur
# <Response [200]>
# Processing Record 3 of Set 1 | mount isa
# <Response [200]>
# Processing Record 4 of Set 1 | invercargill
# <Response [200]>
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# <Response [200]>
# Processing Record 6 of Set 1 | prado
# <Response [200]>
# Processing Record 7 of Set 1 | longyearbyen
# <Response [200]>
# Processing Record 8 of Set 1 | port-aux-francais
# <Response [200]>
# Processing Record 9 of Set 1 | ribeira grande
# <Response [200]>
# Processing Record 10 of Set 1 | waitangi
# <Response [200]>
# Processing Record 11 of Set 1 | margaret river
# <Response [200]>
# Processing Record 12 of Set 1 | olonkinbyen
# <Response [200]>
# Processing Record 13 of Set 1 | bredasdorp
# <Response [200]>
# Processing Record 14 of Set 1 | claveria
# <Response [200]>
# Processing Record 15 of Set 1 | puerto natales
# <Response [200]>
# Processing Record 16 of Set 1 | bethel
# <Response [200]>
# Processing Record 17 of Set 1 | wailua homesteads
# <Response [200]>
# Processing Record 18 of Set 1 | whitehorse
# <Response [200]>
# Processing Record 19 of Set 1 | santa barbara
# <Response [200]>
# Processing Record 20 of Set 1 | pimentel
# <Response [200]>
# Processing Record 21 of Set 1 | puerto san carlos
# <Response [404]>
# City not found. Skipping...
# Processing Record 22 of Set 1 | myrina
# <Response [200]>
# Processing Record 23 of Set 1 | albany
# <Response [200]>
# Processing Record 24 of Set 1 | corry
# <Response [200]>
# Processing Record 25 of Set 1 | shenkursk
# <Response [200]>
# Processing Record 26 of Set 1 | iskateley
# <Response [200]>
# Processing Record 27 of Set 1 | vilyuchinsk
# <Response [200]>
# Processing Record 28 of Set 1 | sao tome
# <Response [200]>
# Processing Record 29 of Set 1 | isafjordur
# <Response [200]>
# Processing Record 30 of Set 1 | isola di capo rizzuto
# <Response [200]>
# Processing Record 31 of Set 1 | vallenar
# <Response [200]>
# Processing Record 32 of Set 1 | anadyr
# <Response [200]>
# Processing Record 33 of Set 1 | rauco
# <Response [200]>
# Processing Record 34 of Set 1 | sao jose da coroa grande
# <Response [200]>
# Processing Record 35 of Set 1 | utrik
# <Response [200]>
# Processing Record 36 of Set 1 | grytviken
# <Response [200]>
# Processing Record 37 of Set 1 | immokalee
# <Response [200]>
# Processing Record 38 of Set 1 | maridi
# <Response [200]>
# Processing Record 39 of Set 1 | georgetown
# <Response [200]>
# Processing Record 40 of Set 1 | plastun
# <Response [200]>
# Processing Record 41 of Set 1 | tiksi
# <Response [200]>
# Processing Record 42 of Set 1 | luganville
# <Response [200]>
# Processing Record 43 of Set 1 | ketchikan
# <Response [200]>
# Processing Record 44 of Set 1 | mahanoro
# <Response [200]>
# Processing Record 45 of Set 1 | hamilton
# <Response [200]>
# Processing Record 46 of Set 1 | codrington
# <Response [200]>
# Processing Record 47 of Set 1 | kulunda
# <Response [200]>
# Processing Record 48 of Set 1 | tralee
# <Response [200]>
# Processing Record 49 of Set 1 | bilibino
# <Response [200]>
# Processing Record 50 of Set 1 | fort bragg
# <Response [200]>
# Processing Record 0 of Set 2 | hithadhoo
# <Response [200]>
# Processing Record 1 of Set 2 | prachuap khiri khan
# <Response [200]>
# Processing Record 2 of Set 2 | ushuaia
# <Response [200]>
# Processing Record 3 of Set 2 | sitka
# <Response [200]>
# Processing Record 4 of Set 2 | toga village
# <Response [404]>
# City not found. Skipping...
# Processing Record 5 of Set 2 | ponta delgada
# <Response [200]>
# Processing Record 6 of Set 2 | bubaque
# <Response [200]>
# Processing Record 7 of Set 2 | udachny
# <Response [200]>
# Processing Record 8 of Set 2 | mulanje
# <Response [200]>
# Processing Record 9 of Set 2 | kapuskasing
# <Response [200]>
# Processing Record 10 of Set 2 | holualoa
# <Response [200]>
# Processing Record 11 of Set 2 | princeville
# <Response [200]>
# Processing Record 12 of Set 2 | avarua
# <Response [200]>
# Processing Record 13 of Set 2 | labuan
# <Response [200]>
# Processing Record 14 of Set 2 | suva
# <Response [200]>
# Processing Record 15 of Set 2 | santa ana
# <Response [200]>
# Processing Record 16 of Set 2 | tazacorte
# <Response [200]>
# Processing Record 17 of Set 2 | taiohae
# <Response [404]>
# City not found. Skipping...
# Processing Record 18 of Set 2 | birjand
# <Response [200]>
# Processing Record 19 of Set 2 | san rafael
# <Response [200]>
# Processing Record 20 of Set 2 | blackmans bay
# <Response [200]>
# Processing Record 21 of Set 2 | olinda
# <Response [200]>
# Processing Record 22 of Set 2 | burang
# <Response [200]>
# Processing Record 23 of Set 2 | ba
# <Response [404]>
# City not found. Skipping...
# Processing Record 24 of Set 2 | bratsk
# <Response [200]>
# Processing Record 25 of Set 2 | thompson
# <Response [200]>
# Processing Record 26 of Set 2 | fuglafjordur
# <Response [200]>
# Processing Record 27 of Set 2 | west island
# <Response [200]>
# Processing Record 28 of Set 2 | callao
# <Response [200]>
# Processing Record 29 of Set 2 | pisco
# <Response [200]>
# Processing Record 30 of Set 2 | mirai
# <Response [200]>
# Processing Record 31 of Set 2 | iqaluit
# <Response [200]>
# Processing Record 32 of Set 2 | petropavlovsk-kamchatsky
# <Response [200]>
# Processing Record 33 of Set 2 | mount gambier
# <Response [200]>
# Processing Record 34 of Set 2 | byron bay
# <Response [200]>
# Processing Record 35 of Set 2 | kone
# <Response [200]>
# Processing Record 36 of Set 2 | medina del campo
# <Response [200]>
# Processing Record 37 of Set 2 | saipan
# <Response [200]>
# Processing Record 38 of Set 2 | ardakan
# <Response [200]>
# Processing Record 39 of Set 2 | juan griego
# <Response [200]>
# Processing Record 40 of Set 2 | antakotako
# <Response [404]>
# City not found. Skipping...
# Processing Record 41 of Set 2 | aripuana
# <Response [200]>
# Processing Record 42 of Set 2 | stanley
# <Response [200]>
# Processing Record 43 of Set 2 | port elizabeth
# <Response [200]>
# Processing Record 44 of Set 2 | puerto baquerizo moreno
# <Response [200]>
# Processing Record 45 of Set 2 | punta arenas
# <Response [200]>
# Processing Record 46 of Set 2 | igarka
# <Response [200]>
# Processing Record 47 of Set 2 | dryden
# <Response [200]>
# Processing Record 48 of Set 2 | berezovo
# <Response [200]>
# Processing Record 49 of Set 2 | cole harbour
# <Response [200]>
# Processing Record 0 of Set 3 | saint-philippe
# <Response [200]>
# Processing Record 1 of Set 3 | port lincoln
# <Response [200]>
# Processing Record 2 of Set 3 | kamaishi
# <Response [200]>
# Processing Record 3 of Set 3 | kavaratti
# <Response [200]>
# Processing Record 4 of Set 3 | nova sintra
# <Response [200]>
# Processing Record 5 of Set 3 | greenville
# <Response [200]>
# Processing Record 6 of Set 3 | selfoss
# <Response [200]>
# Processing Record 7 of Set 3 | san fernando
# <Response [200]>
# Processing Record 8 of Set 3 | lihue
# <Response [200]>
# Processing Record 9 of Set 3 | scarborough
# <Response [200]>
# Processing Record 10 of Set 3 | selkirk
# <Response [200]>
# Processing Record 11 of Set 3 | alofi
# <Response [200]>
# Processing Record 12 of Set 3 | auki
# <Response [200]>
# Processing Record 13 of Set 3 | port alfred
# <Response [200]>
# Processing Record 14 of Set 3 | marsh harbour
# <Response [200]>
# Processing Record 15 of Set 3 | nagqu
# <Response [200]>
# Processing Record 16 of Set 3 | lompoc
# <Response [200]>
# Processing Record 17 of Set 3 | port mathurin
# <Response [200]>
# Processing Record 18 of Set 3 | santa cruz
# <Response [200]>
# Processing Record 19 of Set 3 | wagar
# <Response [200]>
# Processing Record 20 of Set 3 | san juan de miraflores
# <Response [200]>
# Processing Record 21 of Set 3 | lebu
# <Response [200]>
# Processing Record 22 of Set 3 | ust-tsilma
# <Response [200]>
# Processing Record 23 of Set 3 | smara
# <Response [200]>
# Processing Record 24 of Set 3 | port augusta
# <Response [200]>
# Processing Record 25 of Set 3 | namtsy
# <Response [200]>
# Processing Record 26 of Set 3 | kodiak
# <Response [200]>
# Processing Record 27 of Set 3 | barah
# <Response [200]>
# Processing Record 28 of Set 3 | mount pearl
# <Response [200]>
# Processing Record 29 of Set 3 | usinsk
# <Response [200]>
# Processing Record 30 of Set 3 | afaahiti
# <Response [200]>
# Processing Record 31 of Set 3 | puerto aysen
# <Response [200]>
# Processing Record 32 of Set 3 | miyoshi
# <Response [200]>
# Processing Record 33 of Set 3 | la serena
# <Response [200]>
# Processing Record 34 of Set 3 | hadibu
# <Response [200]>
# Processing Record 35 of Set 3 | camana
# <Response [200]>
# Processing Record 36 of Set 3 | lugoba
# <Response [200]>
# Processing Record 37 of Set 3 | skagen
# <Response [200]>
# Processing Record 38 of Set 3 | vorgashor
# <Response [200]>
# Processing Record 39 of Set 3 | salekhard
# <Response [200]>
# Processing Record 40 of Set 3 | ouellah
# <Response [404]>
# City not found. Skipping...
# Processing Record 41 of Set 3 | cockburn town
# <Response [200]>
# Processing Record 42 of Set 3 | chukhloma
# <Response [200]>
# Processing Record 43 of Set 3 | sedan
# <Response [200]>
# Processing Record 44 of Set 3 | atafu village
# <Response [200]>
# Processing Record 45 of Set 3 | ust-nera
# <Response [200]>
# Processing Record 46 of Set 3 | carnarvon
# <Response [200]>
# Processing Record 47 of Set 3 | taoudenni
# <Response [200]>
# Processing Record 48 of Set 3 | yellowknife
# <Response [200]>
# Processing Record 49 of Set 3 | mili
# <Response [200]>
# Processing Record 0 of Set 4 | shimoda
# <Response [200]>
# Processing Record 1 of Set 4 | aykhal
# <Response [200]>
# Processing Record 2 of Set 4 | lazaro cardenas
# <Response [200]>
# Processing Record 3 of Set 4 | fale old settlement
# <Response [200]>
# Processing Record 4 of Set 4 | misliyah
# <Response [200]>
# Processing Record 5 of Set 4 | dudinka
# <Response [200]>
# Processing Record 6 of Set 4 | warrenton
# <Response [200]>
# Processing Record 7 of Set 4 | aasiaat
# <Response [200]>
# Processing Record 8 of Set 4 | byala slatina
# <Response [200]>
# Processing Record 9 of Set 4 | guerrero negro
# <Response [200]>
# Processing Record 10 of Set 4 | kurumkan
# <Response [200]>
# Processing Record 11 of Set 4 | bandar abbas
# <Response [200]>
# Processing Record 12 of Set 4 | haradok
# <Response [200]>
# Processing Record 13 of Set 4 | santa marta
# <Response [200]>
# Processing Record 14 of Set 4 | tofol
# <Response [200]>
# Processing Record 15 of Set 4 | san martin
# <Response [200]>
# Processing Record 16 of Set 4 | albu kamal
# <Response [200]>
# Processing Record 17 of Set 4 | bac lieu
# <Response [200]>
# Processing Record 18 of Set 4 | mil'kovo
# <Response [200]>
# Processing Record 19 of Set 4 | thames
# <Response [200]>
# Processing Record 20 of Set 4 | enewetak
# <Response [200]>
# Processing Record 21 of Set 4 | mgandu
# <Response [200]>
# Processing Record 22 of Set 4 | labrador city
# <Response [200]>
# Processing Record 23 of Set 4 | qamdo
# <Response [200]>
# Processing Record 24 of Set 4 | cabo san lucas
# <Response [200]>
# Processing Record 25 of Set 4 | remire-montjoly
# <Response [200]>
# Processing Record 26 of Set 4 | udpura
# <Response [200]>
# Processing Record 27 of Set 4 | purwa
# <Response [200]>
# Processing Record 28 of Set 4 | segou
# <Response [200]>
# Processing Record 29 of Set 4 | college
# <Response [200]>
# Processing Record 30 of Set 4 | akcaabat
# <Response [200]>
# Processing Record 31 of Set 4 | kristiansund
# <Response [200]>
# Processing Record 32 of Set 4 | ma'rib
# <Response [200]>
# Processing Record 33 of Set 4 | constantia
# <Response [200]>
# Processing Record 34 of Set 4 | hawaiian paradise park
# <Response [200]>
# Processing Record 35 of Set 4 | magadan
# <Response [200]>
# Processing Record 36 of Set 4 | kununurra
# <Response [200]>
# Processing Record 37 of Set 4 | al bawiti
# <Response [200]>
# Processing Record 38 of Set 4 | starodub
# <Response [200]>
# Processing Record 39 of Set 4 | tamanrasset
# <Response [200]>
# Processing Record 40 of Set 4 | odienne
# <Response [200]>
# Processing Record 41 of Set 4 | guiria
# <Response [404]>
# City not found. Skipping...
# Processing Record 42 of Set 4 | harper
# <Response [200]>
# Processing Record 43 of Set 4 | sandnessjoen
# <Response [200]>
# Processing Record 44 of Set 4 | kiama
# <Response [200]>
# Processing Record 45 of Set 4 | glace bay
# <Response [200]>
# Processing Record 46 of Set 4 | strathalbyn
# <Response [200]>
# Processing Record 47 of Set 4 | urangan
# <Response [200]>
# Processing Record 48 of Set 4 | ontinyent
# <Response [200]>
# Processing Record 49 of Set 4 | puerto ayora
# <Response [200]>
# Processing Record 0 of Set 5 | corn island
# <Response [200]>
# Processing Record 1 of Set 5 | ilulissat
# <Response [200]>
# Processing Record 2 of Set 5 | male
# <Response [200]>
# Processing Record 3 of Set 5 | haiku-pauwela
# <Response [200]>
# Processing Record 4 of Set 5 | namdrik
# <Response [200]>
# Processing Record 5 of Set 5 | st. john's
# <Response [200]>
# Processing Record 6 of Set 5 | san antonio de pale
# <Response [200]>
# Processing Record 7 of Set 5 | taro
# <Response [200]>
# Processing Record 8 of Set 5 | papatowai
# <Response [200]>
# Processing Record 9 of Set 5 | grabouw
# <Response [200]>
# Processing Record 10 of Set 5 | vingt cinq
# <Response [404]>
# City not found. Skipping...
# Processing Record 11 of Set 5 | la mohammedia
# <Response [200]>
# Processing Record 12 of Set 5 | kil'mez'
# <Response [404]>
# City not found. Skipping...
# Processing Record 13 of Set 5 | jashpurnagar
# <Response [200]>
# Processing Record 14 of Set 5 | tazovsky
# <Response [200]>
# Processing Record 15 of Set 5 | rabaul
# <Response [200]>
# Processing Record 16 of Set 5 | alice springs
# <Response [200]>
# Processing Record 17 of Set 5 | vilhena
# <Response [200]>
# Processing Record 18 of Set 5 | kohat
# <Response [200]>
# Processing Record 19 of Set 5 | dongobesh
# <Response [200]>
# Processing Record 20 of Set 5 | san juan
# <Response [200]>
# Processing Record 21 of Set 5 | ilam
# <Response [200]>
# Processing Record 22 of Set 5 | dera bugti
# <Response [200]>
# Processing Record 23 of Set 5 | fort-shevchenko
# <Response [200]>
# Processing Record 24 of Set 5 | vernon
# <Response [200]>
# Processing Record 25 of Set 5 | luderitz
# <Response [200]>
# Processing Record 26 of Set 5 | sisimiut
# <Response [200]>
# Processing Record 27 of Set 5 | kokopo
# <Response [200]>
# Processing Record 28 of Set 5 | lerwick
# <Response [200]>
# Processing Record 29 of Set 5 | kismayo
# <Response [200]>
# Processing Record 30 of Set 5 | kruisfontein
# <Response [200]>
# Processing Record 31 of Set 5 | narasannapeta
# <Response [200]>
# Processing Record 32 of Set 5 | mar del plata
# <Response [200]>
# Processing Record 33 of Set 5 | keetmanshoop
# <Response [200]>
# Processing Record 34 of Set 5 | tanrake village
# <Response [404]>
# City not found. Skipping...
# Processing Record 35 of Set 5 | prince rupert
# <Response [200]>
# Processing Record 36 of Set 5 | flin flon
# <Response [200]>
# Processing Record 37 of Set 5 | qaqortoq
# <Response [200]>
# Processing Record 38 of Set 5 | minas de marcona
# <Response [200]>
# Processing Record 39 of Set 5 | chonchi
# <Response [200]>
# Processing Record 40 of Set 5 | egilsstadir
# <Response [200]>
# Processing Record 41 of Set 5 | eyl
# <Response [200]>
# Processing Record 42 of Set 5 | fuvahmulah
# <Response [404]>
# City not found. Skipping...
# Processing Record 43 of Set 5 | dosso
# <Response [200]>
# Processing Record 44 of Set 5 | coquimbo
# <Response [200]>
# Processing Record 45 of Set 5 | nuevo arraijan
# <Response [200]>
# Processing Record 46 of Set 5 | colonia
# <Response [200]>
# Processing Record 47 of Set 5 | rio grande
# <Response [200]>
# Processing Record 48 of Set 5 | cadillac
# <Response [200]>
# Processing Record 49 of Set 5 | port lavaca
# <Response [200]>
# Processing Record 0 of Set 6 | liberty lake
# <Response [200]>
# Processing Record 1 of Set 6 | jayapura
# <Response [200]>
# Processing Record 2 of Set 6 | karditsa
# <Response [200]>
# Processing Record 3 of Set 6 | kitwe
# <Response [200]>
# Processing Record 4 of Set 6 | yungay
# <Response [200]>
# Processing Record 5 of Set 6 | puerto deseado
# <Response [200]>
# Processing Record 6 of Set 6 | puerto carreno
# <Response [200]>
# Processing Record 7 of Set 6 | harsud
# <Response [200]>
# Processing Record 8 of Set 6 | tasbuget
# <Response [404]>
# City not found. Skipping...
# Processing Record 9 of Set 6 | las lajitas
# <Response [200]>
# Processing Record 10 of Set 6 | usogorsk
# <Response [200]>
# Processing Record 11 of Set 6 | porto novo
# <Response [200]>
# Processing Record 12 of Set 6 | kapa'a
# <Response [200]>
# Processing Record 13 of Set 6 | crane
# <Response [200]>
# Processing Record 14 of Set 6 | klyuchi
# <Response [200]>
# Processing Record 15 of Set 6 | ayaguz
# <Response [404]>
# City not found. Skipping...
# Processing Record 16 of Set 6 | emerald
# <Response [200]>
# Processing Record 17 of Set 6 | zapolyarnyy
# <Response [200]>
# Processing Record 18 of Set 6 | yylanly
# <Response [404]>
# City not found. Skipping...
# Processing Record 19 of Set 6 | la'ie
# <Response [200]>
# Processing Record 20 of Set 6 | rukban
# <Response [404]>
# City not found. Skipping...
# Processing Record 21 of Set 6 | praia da vitoria
# <Response [200]>
# Processing Record 22 of Set 6 | matoury
# <Response [200]>
# Processing Record 23 of Set 6 | vadso
# <Response [200]>
# Processing Record 24 of Set 6 | khovd
# <Response [200]>
# Processing Record 25 of Set 6 | port isabel
# <Response [200]>
# Processing Record 26 of Set 6 | port blair
# <Response [200]>
# Processing Record 27 of Set 6 | bamyan
# <Response [200]>
# Processing Record 28 of Set 6 | port sudan
# <Response [200]>
# Processing Record 29 of Set 6 | polyarnyy
# <Response [200]>
# Processing Record 30 of Set 6 | flying fish cove
# <Response [200]>
# Processing Record 31 of Set 6 | lom sak
# <Response [200]>
# Processing Record 32 of Set 6 | timimoun
# <Response [200]>
# Processing Record 33 of Set 6 | 'ohonua
# <Response [404]>
# City not found. Skipping...
# Processing Record 34 of Set 6 | tura
# <Response [200]>
# Processing Record 35 of Set 6 | masjed soleyman
# <Response [200]>
# Processing Record 36 of Set 6 | jamestown
# <Response [200]>
# Processing Record 37 of Set 6 | khandyga
# <Response [200]>
# Processing Record 38 of Set 6 | al jawf
# <Response [200]>
# Processing Record 39 of Set 6 | illizi
# <Response [200]>
# Processing Record 40 of Set 6 | kamenka
# <Response [200]>
# Processing Record 41 of Set 6 | ar rutbah
# <Response [200]>
# Processing Record 42 of Set 6 | vorkuta
# <Response [200]>
# Processing Record 43 of Set 6 | anshun
# <Response [200]>
# Processing Record 44 of Set 6 | durban
# <Response [200]>
# Processing Record 45 of Set 6 | lubao
# <Response [200]>
# Processing Record 46 of Set 6 | narimanov
# <Response [200]>
# Processing Record 47 of Set 6 | al 'amarah
# <Response [200]>
# Processing Record 48 of Set 6 | yagry
# <Response [404]>
# City not found. Skipping...
# Processing Record 49 of Set 6 | nar'yan-mar
# <Response [200]>
# Processing Record 0 of Set 7 | kailua-kona
# <Response [200]>
# Processing Record 1 of Set 7 | touros
# <Response [200]>
# Processing Record 2 of Set 7 | linfen
# <Response [200]>
# Processing Record 3 of Set 7 | harnosand
# <Response [200]>
# Processing Record 4 of Set 7 | talcahuano
# <Response [200]>
# Processing Record 5 of Set 7 | joao pinheiro
# <Response [200]>
# Processing Record 6 of Set 7 | vila franca do campo
# <Response [200]>
# Processing Record 7 of Set 7 | agadez
# <Response [200]>
# Processing Record 8 of Set 7 | yarmouth
# <Response [200]>
# Processing Record 9 of Set 7 | yuzhno-kurilsk
# <Response [200]>
# Processing Record 10 of Set 7 | tranovaho
# <Response [404]>
# City not found. Skipping...
# Processing Record 11 of Set 7 | cargados carajos
# <Response [404]>
# City not found. Skipping...
# Processing Record 12 of Set 7 | saint-louis
# <Response [200]>
# Processing Record 13 of Set 7 | sabha
# <Response [200]>
# Processing Record 14 of Set 7 | zaozersk
# <Response [200]>
# Processing Record 15 of Set 7 | griffith
# <Response [200]>
# Processing Record 16 of Set 7 | badger
# <Response [200]>
# Processing Record 17 of Set 7 | maysville
# <Response [200]>
# Processing Record 18 of Set 7 | tirumullaivasal
# <Response [200]>
# Processing Record 19 of Set 7 | rongelap
# <Response [200]>
# Processing Record 20 of Set 7 | susuman
# <Response [200]>
# Processing Record 21 of Set 7 | jabal os saraj
# <Response [200]>
# Processing Record 22 of Set 7 | hammerfest
# <Response [200]>
# Processing Record 23 of Set 7 | rikaze
# <Response [200]>
# Processing Record 24 of Set 7 | quellon
# <Response [200]>
# Processing Record 25 of Set 7 | daru
# <Response [200]>
# Processing Record 26 of Set 7 | porto franco
# <Response [200]>
# Processing Record 27 of Set 7 | san pedro
# <Response [200]>
# Processing Record 28 of Set 7 | san felipe
# <Response [200]>
# Processing Record 29 of Set 7 | nadi
# <Response [200]>
# Processing Record 30 of Set 7 | karratha
# <Response [200]>
# Processing Record 31 of Set 7 | bonthe
# <Response [200]>
# Processing Record 32 of Set 7 | happy valley-goose bay
# <Response [200]>
# Processing Record 33 of Set 7 | tuchow
# <Response [200]>
# Processing Record 34 of Set 7 | kolonia town
# <Response [200]>
# Processing Record 35 of Set 7 | tindouf
# <Response [200]>
# Processing Record 36 of Set 7 | manteno
# <Response [200]>
# Processing Record 37 of Set 7 | kuta
# <Response [200]>
# Processing Record 38 of Set 7 | verkhotur'ye
# <Response [200]>
# Processing Record 39 of Set 7 | poxoreo
# <Response [200]>
# Processing Record 40 of Set 7 | namibe
# <Response [200]>
# Processing Record 41 of Set 7 | forrest city
# <Response [200]>
# Processing Record 42 of Set 7 | terekeka
# <Response [404]>
# City not found. Skipping...
# Processing Record 43 of Set 7 | choyr
# <Response [200]>
# Processing Record 44 of Set 7 | carutapera
# <Response [200]>
# Processing Record 45 of Set 7 | ust'-ilimsk
# <Response [200]>
# Processing Record 46 of Set 7 | kingston
# <Response [200]>
# Processing Record 47 of Set 7 | howard springs
# <Response [200]>
# Processing Record 48 of Set 7 | east honolulu
# <Response [404]>
# City not found. Skipping...
# Processing Record 49 of Set 7 | pirgaaj
# <Response [200]>
# Processing Record 0 of Set 8 | tual
# <Response [200]>
# Processing Record 1 of Set 8 | brookings
# <Response [200]>
# Processing Record 2 of Set 8 | suileng
# <Response [200]>
# Processing Record 3 of Set 8 | strathmore
# <Response [200]>
# Processing Record 4 of Set 8 | talnakh
# <Response [200]>
# Processing Record 5 of Set 8 | saldanha
# <Response [200]>
# Processing Record 6 of Set 8 | cofradia
# <Response [200]>
# Processing Record 7 of Set 8 | hanceville
# <Response [200]>
# Processing Record 8 of Set 8 | zaragoza
# <Response [200]>
# Processing Record 9 of Set 8 | puerto real
# <Response [200]>
# Processing Record 10 of Set 8 | kampong thom
# <Response [200]>
# Processing Record 11 of Set 8 | pacific grove
# <Response [200]>
# Processing Record 12 of Set 8 | kourou
# <Response [200]>
# Processing Record 13 of Set 8 | valley center
# <Response [200]>
# Processing Record 14 of Set 8 | ratnagiri
# <Response [200]>
# Processing Record 15 of Set 8 | toliara
# <Response [200]>
# Processing Record 16 of Set 8 | ceeldheer
# <Response [200]>
# Processing Record 17 of Set 8 | feijo
# <Response [200]>
# Processing Record 18 of Set 8 | gamba
# <Response [200]>
# Processing Record 19 of Set 8 | portland
# <Response [200]>
# Processing Record 20 of Set 8 | acarau
# <Response [200]>
# Processing Record 21 of Set 8 | ciudad melchor muzquiz
# <Response [200]>
# Processing Record 22 of Set 8 | kande
# <Response [200]>
# Processing Record 23 of Set 8 | tolanaro
# <Response [200]>
# Processing Record 24 of Set 8 | machico
# <Response [200]>
# Processing Record 25 of Set 8 | lobujya
# <Response [200]>
# Processing Record 26 of Set 8 | ankang
# <Response [200]>
# Processing Record 27 of Set 8 | riachao das neves
# <Response [200]>
# Processing Record 28 of Set 8 | hegang
# <Response [200]>
# Processing Record 29 of Set 8 | narasaraopet
# <Response [200]>
# Processing Record 30 of Set 8 | bayindir
# <Response [200]>
# Processing Record 31 of Set 8 | pibor
# <Response [404]>
# City not found. Skipping...
# Processing Record 32 of Set 8 | nelson bay
# <Response [200]>
# Processing Record 33 of Set 8 | pereval's'k
# <Response [200]>
# Processing Record 34 of Set 8 | sydney
# <Response [200]>
# Processing Record 35 of Set 8 | nueva esperanza
# <Response [200]>
# Processing Record 36 of Set 8 | anabar
# <Response [404]>
# City not found. Skipping...
# Processing Record 37 of Set 8 | motygino
# <Response [200]>
# Processing Record 38 of Set 8 | camaguey
# <Response [200]>
# Processing Record 39 of Set 8 | dunedin
# <Response [200]>
# Processing Record 40 of Set 8 | howrah
# <Response [200]>
# Processing Record 41 of Set 8 | margate
# <Response [200]>
# Processing Record 42 of Set 8 | bowen
# <Response [200]>
# Processing Record 43 of Set 8 | kill devil hills
# <Response [200]>
# Processing Record 44 of Set 8 | cestos city
# <Response [200]>
# Processing Record 45 of Set 8 | zhangjiakou
# <Response [200]>
# Processing Record 46 of Set 8 | cadale
# <Response [200]>
# Processing Record 47 of Set 8 | katsuren-haebaru
# <Response [200]>
# Processing Record 48 of Set 8 | james island
# <Response [404]>
# City not found. Skipping...
# Processing Record 49 of Set 8 | yelovo
# <Response [200]>
# Processing Record 0 of Set 9 | peace river
# <Response [200]>
# Processing Record 1 of Set 9 | sao joao da barra
# <Response [200]>
# Processing Record 2 of Set 9 | masterton
# <Response [200]>
# Processing Record 3 of Set 9 | camapua
# <Response [200]>
# Processing Record 4 of Set 9 | kargasok
# <Response [200]>
# Processing Record 5 of Set 9 | tyuratam
# <Response [200]>
# Processing Record 6 of Set 9 | suoyarvi
# <Response [200]>
# Processing Record 7 of Set 9 | togur
# <Response [200]>
# Processing Record 8 of Set 9 | gladstone
# <Response [200]>
# Processing Record 9 of Set 9 | chibougamau
# <Response [200]>
# Processing Record 10 of Set 9 | galliano
# <Response [200]>
# Processing Record 11 of Set 9 | justo daract
# <Response [200]>
# Processing Record 12 of Set 9 | kimbe
# <Response [200]>
# Processing Record 13 of Set 9 | sinop
# <Response [200]>
# Processing Record 14 of Set 9 | mirny
# <Response [200]>
# Processing Record 15 of Set 9 | santa terezinha
# <Response [200]>
# Processing Record 16 of Set 9 | marica
# <Response [200]>
# Processing Record 17 of Set 9 | shingu
# <Response [200]>
# Processing Record 18 of Set 9 | kurchatov
# <Response [200]>
# Processing Record 19 of Set 9 | nemuro
# <Response [200]>
# Processing Record 20 of Set 9 | darwin
# <Response [200]>
# Processing Record 21 of Set 9 | oroqen zizhiqi
# <Response [200]>
# Processing Record 22 of Set 9 | big spring
# <Response [200]>
# Processing Record 23 of Set 9 | arraial do cabo
# <Response [200]>
# Processing Record 24 of Set 9 | broome
# <Response [200]>
# Processing Record 25 of Set 9 | gobabis
# <Response [200]>
# Processing Record 26 of Set 9 | itambe
# <Response [200]>
# Processing Record 27 of Set 9 | camalu
# <Response [200]>
# Processing Record 28 of Set 9 | ares
# <Response [200]>
# Processing Record 29 of Set 9 | bandarbeyla
# <Response [200]>
# Processing Record 30 of Set 9 | st. paul
# <Response [200]>
# Processing Record 31 of Set 9 | sao vicente
# <Response [200]>
# Processing Record 32 of Set 9 | jiayuguan
# <Response [200]>
# Processing Record 33 of Set 9 | vuktyl
# <Response [200]>
# Processing Record 34 of Set 9 | freetown
# <Response [200]>
# Processing Record 35 of Set 9 | sumbawa besar
# <Response [200]>
# Processing Record 36 of Set 9 | espargos
# <Response [404]>
# City not found. Skipping...
# Processing Record 37 of Set 9 | colachel
# <Response [200]>
# Processing Record 38 of Set 9 | hermanus
# <Response [200]>
# Processing Record 39 of Set 9 | vavuniya
# <Response [200]>
# Processing Record 40 of Set 9 | bardai
# <Response [200]>
# Processing Record 41 of Set 9 | cill airne
# <Response [200]>
# Processing Record 42 of Set 9 | yingkou
# <Response [200]>
# Processing Record 43 of Set 9 | sittwe
# <Response [200]>
# Processing Record 44 of Set 9 | correntina
# <Response [200]>
# Processing Record 45 of Set 9 | tshabong
# <Response [200]>
# Processing Record 46 of Set 9 | marsa alam
# <Response [200]>
# Processing Record 47 of Set 9 | staunton
# <Response [200]>
# Processing Record 48 of Set 9 | ust'-kut
# <Response [200]>
# Processing Record 49 of Set 9 | joal-fadiout
# <Response [200]>
# Processing Record 0 of Set 10 | rawson
# <Response [200]>
# Processing Record 1 of Set 10 | assab
# <Response [200]>
# Processing Record 2 of Set 10 | el abiodh sidi cheikh
# <Response [200]>
# Processing Record 3 of Set 10 | antofagasta
# <Response [200]>
# Processing Record 4 of Set 10 | kaduy
# <Response [200]>
# Processing Record 5 of Set 10 | madaba
# <Response [200]>
# Processing Record 6 of Set 10 | alo
# <Response [200]>
# Processing Record 7 of Set 10 | babolsar
# <Response [200]>
# Processing Record 8 of Set 10 | thinadhoo
# <Response [200]>
# Processing Record 9 of Set 10 | lepsy
# <Response [200]>
# Processing Record 10 of Set 10 | jiehu
# <Response [200]>
# Processing Record 11 of Set 10 | muriti
# <Response [200]>
# Processing Record 12 of Set 10 | progreso
# <Response [200]>
# Processing Record 13 of Set 10 | agartala
# <Response [200]>
# Processing Record 14 of Set 10 | revda
# <Response [200]>
# Processing Record 15 of Set 10 | turpan
# <Response [200]>
# Processing Record 16 of Set 10 | bikenibeu village
# <Response [200]>
# Processing Record 17 of Set 10 | isangel
# <Response [200]>
# Processing Record 18 of Set 10 | port hedland
# <Response [200]>
# Processing Record 19 of Set 10 | manacapuru
# <Response [200]>
# Processing Record 20 of Set 10 | kiunga
# <Response [200]>
# Processing Record 21 of Set 10 | zhoucun
# <Response [200]>
# Processing Record 22 of Set 10 | kharsia
# <Response [200]>
# Processing Record 23 of Set 10 | demmin
# <Response [200]>
# Processing Record 24 of Set 10 | xianyang
# <Response [200]>
# Processing Record 25 of Set 10 | tyukalinsk
# <Response [200]>
# Processing Record 26 of Set 10 | la passe
# <Response [200]>
# Processing Record 27 of Set 10 | puri
# <Response [200]>
# Processing Record 28 of Set 10 | tupaciguara
# <Response [200]>
# Processing Record 29 of Set 10 | gadzhiyevo
# <Response [200]>
# Processing Record 30 of Set 10 | benton
# <Response [200]>
# Processing Record 31 of Set 10 | whyalla stuart
# <Response [404]>
# City not found. Skipping...
# Processing Record 32 of Set 10 | okahandja
# <Response [200]>
# Processing Record 33 of Set 10 | khanty-mansiysk
# <Response [200]>
# Processing Record 34 of Set 10 | popondetta
# <Response [200]>
# Processing Record 35 of Set 10 | buka
# <Response [200]>
# Processing Record 36 of Set 10 | cananeia
# <Response [200]>
# Processing Record 37 of Set 10 | mirebalais
# <Response [200]>
# Processing Record 38 of Set 10 | vanimo
# <Response [200]>
# Processing Record 39 of Set 10 | saint-pourcain-sur-sioule
# <Response [200]>
# Processing Record 40 of Set 10 | orsa
# <Response [200]>
# Processing Record 41 of Set 10 | baihe
# <Response [200]>
# Processing Record 42 of Set 10 | point pedro
# <Response [200]>
# Processing Record 43 of Set 10 | manicore
# <Response [200]>
# Processing Record 44 of Set 10 | boyolangu
# <Response [200]>
# Processing Record 45 of Set 10 | merizo village
# <Response [200]>
# Processing Record 46 of Set 10 | gassol
# <Response [200]>
# Processing Record 47 of Set 10 | papao
# <Response [200]>
# Processing Record 48 of Set 10 | retreat
# <Response [200]>
# Processing Record 49 of Set 10 | karayazi
# <Response [200]>
# Processing Record 0 of Set 11 | chui
# <Response [200]>
# Processing Record 1 of Set 11 | sakaiminato
# <Response [200]>
# Processing Record 2 of Set 11 | madison
# <Response [200]>
# Processing Record 3 of Set 11 | kualakapuas
# <Response [200]>
# Processing Record 4 of Set 11 | kataragama
# <Response [404]>
# City not found. Skipping...
# Processing Record 5 of Set 11 | ad dabbah
# <Response [200]>
# Processing Record 6 of Set 11 | thulamahashi
# <Response [200]>
# Processing Record 7 of Set 11 | azadshahr
# <Response [200]>
# Processing Record 8 of Set 11 | hualien city
# <Response [200]>
# Processing Record 9 of Set 11 | fall river
# <Response [200]>
# Processing Record 10 of Set 11 | uvel'skiy
# <Response [200]>
# Processing Record 11 of Set 11 | nyagan
# <Response [200]>
# Processing Record 12 of Set 11 | oranjemund
# <Response [200]>
# Processing Record 13 of Set 11 | nizhneudinsk
# <Response [200]>
# Processing Record 14 of Set 11 | elliot lake
# <Response [200]>
# Processing Record 15 of Set 11 | mount hagen
# <Response [200]>
# Processing Record 16 of Set 11 | aguadilla
# <Response [200]>
# Processing Record 17 of Set 11 | lalibela
# <Response [200]>
# Processing Record 18 of Set 11 | jawf al maqbabah
# <Response [200]>
# Processing Record 19 of Set 11 | fontenay-le-comte
# <Response [200]>
# Processing Record 20 of Set 11 | souillac
# <Response [200]>
# Processing Record 21 of Set 11 | tandil
# <Response [200]>
# Processing Record 22 of Set 11 | trairi
# <Response [200]>
# Processing Record 23 of Set 11 | louga
# <Response [200]>
# Processing Record 24 of Set 11 | manturovo
# <Response [200]>
# Processing Record 25 of Set 11 | paita
# <Response [200]>
# Processing Record 26 of Set 11 | ak-dovurak
# <Response [200]>
# Processing Record 27 of Set 11 | leava
# <Response [200]>
# Processing Record 28 of Set 11 | mantua
# <Response [200]>
# Processing Record 29 of Set 11 | mersa matruh
# <Response [200]>
# Processing Record 30 of Set 11 | uturoa
# <Response [200]>
# Processing Record 31 of Set 11 | kayangel
# <Response [200]>
# Processing Record 32 of Set 11 | fort st. john
# <Response [200]>
# Processing Record 33 of Set 11 | chinde
# <Response [200]>
# Processing Record 34 of Set 11 | camocim
# <Response [200]>
# Processing Record 35 of Set 11 | le moule
# <Response [200]>
# Processing Record 36 of Set 11 | saint-pierre
# <Response [200]>
# Processing Record 37 of Set 11 | ust'-kulom
# <Response [200]>
# Processing Record 38 of Set 11 | kisangani
# <Response [200]>
# Processing Record 39 of Set 11 | vila velha
# <Response [200]>
# Processing Record 40 of Set 11 | pyu
# <Response [200]>
# Processing Record 41 of Set 11 | dembi dolo
# <Response [200]>
# Processing Record 42 of Set 11 | stornoway
# <Response [200]>
# Processing Record 43 of Set 11 | sumbe
# <Response [200]>
# Processing Record 44 of Set 11 | guarapari
# <Response [200]>
# Processing Record 45 of Set 11 | mendefera
# <Response [200]>
# Processing Record 46 of Set 11 | priyutnoye
# <Response [200]>
# Processing Record 47 of Set 11 | tawau
# <Response [200]>
# Processing Record 48 of Set 11 | boca suno
# <Response [200]>
# Processing Record 49 of Set 11 | muynoq
# <Response [200]>
# Processing Record 0 of Set 12 | akureyri
# <Response [200]>
# Processing Record 1 of Set 12 | totness
# <Response [200]>
# Processing Record 2 of Set 12 | arinos
# <Response [200]>
# Processing Record 3 of Set 12 | smithers
# <Response [200]>
# Processing Record 4 of Set 12 | masvingo
# <Response [200]>
# Processing Record 5 of Set 12 | mugia
# <Response [200]>
# Processing Record 6 of Set 12 | waingapu
# <Response [200]>
# Processing Record 7 of Set 12 | leon
# <Response [200]>
# Processing Record 8 of Set 12 | harnai
# <Response [200]>
# Processing Record 9 of Set 12 | yorkton
# <Response [200]>
# Processing Record 10 of Set 12 | gosaba
# <Response [404]>
# City not found. Skipping...
# Processing Record 11 of Set 12 | east london
# <Response [200]>
# Processing Record 12 of Set 12 | conduaga
# <Response [200]>
# Processing Record 13 of Set 12 | kiruna
# <Response [200]>
# Processing Record 14 of Set 12 | pago pago
# <Response [200]>
# Processing Record 15 of Set 12 | al ghayzah
# <Response [200]>
# Processing Record 16 of Set 12 | dolbeau-mistassini
# <Response [200]>
# Processing Record 17 of Set 12 | mutoko
# <Response [200]>
# Processing Record 18 of Set 12 | axim
# <Response [200]>
# Processing Record 19 of Set 12 | abraham's bay
# <Response [404]>
# City not found. Skipping...
# Processing Record 20 of Set 12 | grand gaube
# <Response [200]>
# Processing Record 21 of Set 12 | bria
# <Response [200]>
# Processing Record 22 of Set 12 | bondo
# <Response [200]>
# Processing Record 23 of Set 12 | charleston
# <Response [200]>
# Processing Record 24 of Set 12 | mao
# <Response [200]>
# Processing Record 25 of Set 12 | alampur
# <Response [200]>
# Processing Record 26 of Set 12 | batticaloa
# <Response [200]>
# Processing Record 27 of Set 12 | zyryanovsk
# <Response [200]>
# Processing Record 28 of Set 12 | strezhevoy
# <Response [200]>
# Processing Record 29 of Set 12 | calabozo
# <Response [200]>
# Processing Record 30 of Set 12 | ola
# <Response [200]>
# Processing Record 31 of Set 12 | mweka
# <Response [200]>
# Processing Record 32 of Set 12 | douentza
# <Response [200]>
# Processing Record 33 of Set 12 | el fasher
# <Response [200]>
# Processing Record 34 of Set 12 | augusta
# <Response [200]>
# Processing Record 35 of Set 12 | puerto santa
# <Response [200]>
# Processing Record 36 of Set 12 | wum
# <Response [200]>
# Processing Record 37 of Set 12 | ijuw
# <Response [404]>
# City not found. Skipping...
# Processing Record 38 of Set 12 | antsiranana
# <Response [200]>
# Processing Record 39 of Set 12 | sinan
# <Response [200]>
# Processing Record 40 of Set 12 | roma
# <Response [200]>
# Processing Record 41 of Set 12 | guatrache
# <Response [200]>
# Processing Record 42 of Set 12 | newman
# <Response [200]>
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                    adamstown -25.0660 -130.1015     20.25        65
# 1                 saudarkrokur  65.7461  -19.6394      4.60        96
# 2                    mount isa -20.7333  139.5000     23.87        46
# 3                 invercargill -46.4000  168.3500     11.12        92
# 4  edinburgh of the seven seas -37.0676  -12.3116     15.54        85
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        3.04      PN  1715505336
# 1         100        1.60      IS  1715505336
# 2           7        5.14      AU  1715505337
# 3         100        3.58      NZ  1715505337
# 4         100        4.98      SH  1715505338

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          adamstown -25.0660 -130.1015     20.25        65
# 1                       saudarkrokur  65.7461  -19.6394      4.60        96
# 2                          mount isa -20.7333  139.5000     23.87        46
# 3                       invercargill -46.4000  168.3500     11.12        92
# 4        edinburgh of the seven seas -37.0676  -12.3116     15.54        85
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        3.04      PN  1715505336
# 1               100        1.60      IS  1715505336
# 2                 7        5.14      AU  1715505337
# 3               100        3.58      NZ  1715505337
# 4               100        4.98      SH  1715505338

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude Vs Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude Vs Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude Vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude Vs Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress_plots(x_values, y_values, x_label, y_label, a_cord_x, a_cord_y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Calculate the regression line values
    # regress_values = x_values * slope + intercept
    regress_values = [slope * i + intercept for i in x_values]
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # print (line_eq)
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(a_cord_x,a_cord_y),fontsize=15,color="red")
    # plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    print(f"The r-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>= 0]

# # Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          saudarkrokur  65.7461  -19.6394      4.60        96         100
# 6          longyearbyen  78.2186   15.6401      1.91        69          40
# 8        ribeira grande  38.5167  -28.7000     19.32        94          40
# 11          olonkinbyen  70.9221   -8.7187     -0.34        96         100
# 13             claveria  18.6074  121.0832     29.22        84          41
#
#          Wind Speed Country        Date
# City_ID
# 1              1.60      IS  1715505336
# 6              4.63      SJ  1715505339
# 8              5.14      PT  1715505340
# 11             7.72      SJ  1715505342
# 13             3.85      PH  1715505343

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          adamstown -25.0660 -130.1015     20.25        65
# 2                          mount isa -20.7333  139.5000     23.87        46
# 3                       invercargill -46.4000  168.3500     11.12        92
# 4        edinburgh of the seven seas -37.0676  -12.3116     15.54        85
# 5                              prado -17.3411  -39.2208     23.11        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        3.04      PN  1715505336
# 2                 7        5.14      AU  1715505337
# 3               100        3.58      NZ  1715505337
# 4               100        4.98      SH  1715505338
# 5                18        2.38      BR  1715505338

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Temperature",10,-7)
# Out:
# The r-value is: -0.8269137934570493

# %%
# Linear regression on Southern Hemisphere
linear_regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Temperature",-55,30)
# Out:
# The r-value is: 0.7648868731287765

# %% [markdown]
# ### Discussion about the linear relationship:
#
# - #### Northern Hemisphere:
# It can be seen that as the latitude increases, the temperature decreases. There is a negative linear correlation between latitude and temperature. This is also indicated by the negative gradient/slope in the equation for the linear regression line. The r_value of -0.8269 tells us that the negative correlation is strong.
# This is expected as increasing latitude in the northern hemisphere means getting further from the equator, therefore getting colder.
#
# - #### Southern Hemisphere:
# It can be seen that as the latitude increases, the temperature increases. There is a positive linear correlation between latitude and temperature. This is also indicated by the positive gradient/slope in the equation for the linear regression line. The r_value of 0.7649 tells us that the positive correlation is strong.
# This is expected as increasing latitude in the south hemisphere means getting close to the equator, therefore getting hotter.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity",45,5)
# Out:
# The r-value is: 0.16544442627234504

# %%
# Southern Hemisphere
linear_regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity",-55,30)
# Out:
# The r-value is: 0.09012045952602732

# %% [markdown]
# ### Discussion about the linear relationship:
#
#  - #### Northern Hemisphere:
# It can be seen that as the latitude increases, the humidity increases by a small amount. That is, there is a weak positive linear correlation between latitude and humidity. This is also indicated by the small positive gradient/slope in the equation for the linear regression line.
# The r_value of 0.1654 tells us that the positive correlation is weak.
#
#  - #### Southern Hemisphere:
# It can be seen that as the latitude increases, the humidity increases by a small amount. That is, there is a weak positive linear correlation between latitude and humidity. This is also indicated by the small positive gradient/slope in the equation for the linear regression line.
# The r_value of 0.0901 tells us that the positive correlation is very weak.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness",45,55)
# Out:
# The r-value is: 0.14547307385982514

# %%
# Southern Hemisphere
linear_regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness",-55,65)
# Out:
# The r-value is: 0.1380340150583138

# %% [markdown]
# #### Discussion about the linear relationship:
#
# - #### Northern Hemisphere:
#
# It can be seen that as the latitude increases, the cloudiness increases. That is, there is a weak positive linear correlation between latitude and cloudiness. This is also indicated by the very small positive gradient/slope in the equation for the linear regression line. The r_value of 0.1455 tells us that the negative correlation is very weak.
#
#  - #### Southern Hemisphere:
#
# It can be seen that as the latitude increases, the cloudiness increases. That is, there is a weak positive linear correlation between latitude and cloudiness. This is also indicated by the very small positive gradient/slope in the equation for the linear regression line. The r_value of 0.1380 tells us that the positive correlation is very weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed",0,11)
# Out:
# The r-value is: 0.05914777949665448

# %%
# Southern Hemisphere
linear_regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed",-50,12)
# Out:
# The r-value is: -0.12052513151401278

# %% [markdown]
# #### Discussion about the linear relationship:
#
# - #### Northern Hemisphere:
#
# It can be seen that as the latitude increases, the wind speed increases by a very small amount. That is, there is a very weak positive linear correlation between latitude and wind speed. This is also indicated by the very small positive gradient/slope in the equation for the linear regression line. The r_value of 0.0591 tells us that the positive linear correlation is very weak.
#
#  - #### Southern Hemisphere:
#
# It can be seen that as the latitude increases, the wind speed decreases by a very small amount. That is, there is a very weak negative linear correlation between latitude and wind speed. This is also indicated by the small negative gradient/slope in the equation for the linear regression line. The r_value of -0.1205 tells us that the negative correlation is very weak.
